# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/facun/Downloads/Data Science/internetMundial.csv")
data1 = pd.read_csv("C:/Users/facun/Downloads/Data Science/historico_velocidad_internet.csv")
data2 = pd.read_csv("C:/Users/facun/Downloads/Data Science/velocidadInternetAloLargoDeLosAñosArgentina.csv")

# %%
data["velocidad de conexi¢n promedio"].plot.hist(bins=20, title="Distribucion de velocidad de internet mundial", 
                                          legend = True, color = "#438A73")
# Out:
# <AxesSubplot:title={'center':'Distribucion de velocidad de internet mundial'}, ylabel='Frequency'>

# %%
data.groupby("pais/territorio")["velocidad de conexi¢n promedio"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='pais/territorio'>

# %%
data.head(10).groupby("pais/territorio")["velocidad de conexi¢n promedio"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='pais/territorio'>

# %%
data1.groupby("Provincia")["Mbps (Media de bajada)"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Provincia'>

# %%
data1["Mbps (Media de bajada)"].plot.hist(bins=20, title="Distribucion de velocidad de internet", 
                                          legend = True, color = "#F50101")
# Out:
# <AxesSubplot:title={'center':'Distribucion de velocidad de internet'}, ylabel='Frequency'>

# %%
a = data.head(1)
ar = data1.head(1)
ar1 = ar.drop(['Trimestre'], axis=1)

ar2 =  ar1.rename(columns={'Año':'rango', 'Provincia':'pais/territorio',"Mbps (Media de bajada)" : "velocidad de conexi¢n promedio"})
ar2["rango"] = 2

# %%
df = pd.concat([a,ar2])

# %%
df.groupby("pais/territorio")["velocidad de conexi¢n promedio"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='pais/territorio'>

# %%
f = data.tail(1)
u = data1.tail(1)
u1 = u.drop(['Trimestre'], axis=1)
u2 = u1.rename(columns={'Año':'rango', 'Provincia':'pais/territorio',"Mbps (Media de bajada)" : "velocidad de conexi¢n promedio"})
u2["rango"] = 2
df1 = pd.concat([f,u2])

# %%
df1.groupby("pais/territorio")["velocidad de conexi¢n promedio"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='pais/territorio'>

# %%
prog = data2[data2["Provincia"] == "Tucumán"]

# %%
plt.plot(prog["Año"], prog["Mbps (Media de bajada)"])

# %%
prog1 = data2[data2["Provincia"] == "Capital Federal"]

# %%
plt.plot(prog1["Año"], prog1["Mbps (Media de bajada)"])

# %%
plt.plot(prog1["Año"], prog1["Mbps (Media de bajada)"], label = "intenet buenos aires")
plt.plot(prog["Año"], prog["Mbps (Media de bajada)"], label = "internet tucuman")

plt.xlabel("Años")
plt.ylabel("Mbps")
plt.legend()

# %%
plt.plot(data2["Año"], data2["Mbps (Media de bajada)"], label = "intenet")
